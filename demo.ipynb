# %%
from IPython.display import HTML, display

html = """
<div style="background:#101317; color:#fff; font-family:-apple-system, BlinkMacSystemFont, system-ui, sans-serif; padding:16px; max-width:390px; border-radius:24px; border:1px solid #262a33;">
  <div style="font-size:16px; font-weight:600; margin-bottom:12px;">
    Recommended for you
  </div>

  <!-- Buttons row -->
  <div style="display:flex; justify-content:space-between; gap:8px; margin-bottom:8px;">
    <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
      Yes
    </button>
    <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
      Next suggestion
    </button>
  </div>

  <!-- Watched button -->
  <button style="width:100%; padding:10px; border-radius:999px; border:none; background:#13b94d; color:#000; font-size:14px; font-weight:600; margin-bottom:16px;">
    ✅ I've watched this
  </button>

  <!-- Movie info -->
  <div style="display:flex; gap:12px;">
    <div style="width:70px; height:105px; background:#222; border-radius:8px; display:flex; align-items:center; justify-content:center; font-size:10px; color:#777;">
      Poster
    </div>
    <div style="flex:1;">
      <div style="font-size:16px; font-weight:700; margin-bottom:4px;">
        Dead Poets Society <span style="font-weight:500; color:#aaa;">(1989)</span>
      </div>
      <div style="font-size:13px; color:#8fd27f; margin-bottom:8px;">
        Match: <strong>100%</strong>
      </div>
      <div style="font-size:13px; color:#d0d3dc; margin-bottom:8px;">
        <strong>Synopsis:</strong> At an elite, old-fashioned boarding school, an unorthodox English teacher inspires his students to challenge convention.
      </div>
      <div style="font-size:13px; color:#d0d3dc;">
        <strong>Why we picked this for you:</strong>
        <ul style="margin:4px 0 0 18px; padding:0;">
          <li>Same director as <strong>The Truman Show</strong> (Peter Weir).</li>
          <li>Similar genres: Drama.</li>
          <li>Your friend <strong>gabybrown</strong> has this in their Top 4.</li>
        </ul>
      </div>
    </div>
  </div>
</div>
"""

display(HTML(html))
# Out:
# <div style="background:#101317; color:#fff; font-family:-apple-system, BlinkMacSystemFont, system-ui, sans-serif; padding:16px; max-width:390px; border-radius:24px; border:1px solid #262a33;">
#   <div style="font-size:16px; font-weight:600; margin-bottom:12px;">
#     Recommended for you
#   </div>
#
#   <!-- Buttons row -->
#   <div style="display:flex; justify-content:space-between; gap:8px; margin-bottom:8px;">
#     <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
#       Yes
#     </button>
#     <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
#       Next suggestion
#     </button>
#   </div>
#
#   <!-- Watched button -->
#   <button style="width:100%; padding:10px; border-radius:999px; border:none; background:#13b94d; color:#000; font-size:14px; font-weight:600; margin-bottom:16px;">
# ...

# %%
from IPython.display import HTML, display

movie_title = "Stand by Me"
movie_year = 1986
match_pct = "100%"

html = f"""
<div style="background:#101317; color:#fff; font-family:-apple-system, BlinkMacSystemFont, system-ui, sans-serif; padding:16px; max-width:390px; border-radius:24px; border:1px solid #262a33;">
  <div style="font-size:16px; font-weight:600; margin-bottom:12px;">
    Recommended for you
  </div>

  <!-- Buttons row -->
  <div style="display:flex; justify-content:space-between; gap:8px; margin-bottom:8px;">
    <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
      Yes
    </button>
    <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
    Next suggestion
    </button>
  </div>

  <!-- Watched button -->
  <button style="width:100%; padding:10px; border-radius:999px; border:none; background:#13b94d; color:#000; font-size:14px; font-weight:600; margin-bottom:16px;">
    ✅ I've watched this
  </button>

  <!-- Confirmation text -->
  <div style="font-size:14px; color:#d0d3dc;">
    ✅ <strong>{movie_title}</strong> added to your watchlist.
  </div>

  <div style="font-size:13px; color:#9ba0ad; margin-top:8px;">
    Tap <strong>Next suggestion</strong> to see another recommendation.
  </div>
</div>
"""

display(HTML(html))
# Out:
# <div style="background:#101317; color:#fff; font-family:-apple-system, BlinkMacSystemFont, system-ui, sans-serif; padding:16px; max-width:390px; border-radius:24px; border:1px solid #262a33;">
#   <div style="font-size:16px; font-weight:600; margin-bottom:12px;">
#     Recommended for you
#   </div>
#
#   <!-- Buttons row -->
#   <div style="display:flex; justify-content:space-between; gap:8px; margin-bottom:8px;">
#     <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
#       Yes
#     </button>
#     <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
#     Next suggestion
#     </button>
#   </div>
#
#   <!-- Watched button -->
#   <button style="width:100%; padding:10px; border-radius:999px; border:none; background:#13b94d; color:#000; font-size:14px; font-weight:600; margin-bottom:16px;">
# ...

# %%
from IPython.display import HTML, display

movie_title = "Frozen"

html = f"""
<div style="background:#101317; color:#fff; font-family:-apple-system, BlinkMacSystemFont, system-ui, sans-serif; padding:16px; max-width:390px; border-radius:24px; border:1px solid #262a33;">
  <div style="font-size:16px; font-weight:600; margin-bottom:12px;">
    Recommended for you
  </div>

  <!-- Buttons row -->
  <div style="display:flex; justify-content:space-between; gap:8px; margin-bottom:8px;">
    <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
      👍 Yes
    </button>
    <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
      👎 Next suggestion
    </button>
  </div>

  <!-- Watched button -->
  <button style="width:100%; padding:10px; border-radius:999px; border:none; background:#13b94d; color:#000; font-size:14px; font-weight:600; margin-bottom:16px;">
    ✅ I've watched this
  </button>

  <!-- Already-watched text -->
  <div style="font-size:14px; color:#d0d3dc;">
    👀 You've already watched <strong>{movie_title}</strong>.
  </div>

  <div style="font-size:13px; color:#9ba0ad; margin-top:8px;">
    In a real Letterboxd integration this would jump to the rating screen.
    Here, tap <strong>Next suggestion</strong> to see another movie.
  </div>
</div>
"""

display(HTML(html))
# Out:
# <div style="background:#101317; color:#fff; font-family:-apple-system, BlinkMacSystemFont, system-ui, sans-serif; padding:16px; max-width:390px; border-radius:24px; border:1px solid #262a33;">
#   <div style="font-size:16px; font-weight:600; margin-bottom:12px;">
#     Recommended for you
#   </div>
#
#   <!-- Buttons row -->
#   <div style="display:flex; justify-content:space-between; gap:8px; margin-bottom:8px;">
#     <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
#       👍 Yes
#     </button>
#     <button style="flex:1; padding:8px 4px; border-radius:999px; border:none; background:#ffffff; color:#000; font-size:14px; font-weight:500;">
#       👎 Next suggestion
#     </button>
#   </div>
#
#   <!-- Watched button -->
#   <button style="width:100%; padding:10px; border-radius:999px; border:none; background:#13b94d; color:#000; font-size:14px; font-weight:600; margin-bottom:16px;">
# ...
